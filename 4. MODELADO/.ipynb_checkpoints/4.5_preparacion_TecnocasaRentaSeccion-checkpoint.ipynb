# %% [markdown]
# # 🏘️ Preparación y Selección de Variables para Predicción de Precios Inmobiliarios - Tecnocasa Renta Neta Media por Sección
#
# Este notebook tiene como objetivo preparar un conjunto de datos de viviendas extraído de Tecnocasa para entrenar modelos de predicción de precios. El flujo completo incluye la carga y limpieza de datos. A continuación, se describen los principales bloques del notebook:
#
# #### 🔹 Limpieza de variables
# Se eliminan columnas irrelevantes o redundantes, como identificadores únicos o columnas derivadas del objetivo (`Precio_m2`). Se eliminan columnas irrelevantes o redundantes, así como registros con precios nulos o no válidos. Además, se excluyen barrios con pocos inmuebles para garantizar representatividad.
#
# #### 🔹 Filtrado por varianza
# Se eliminan variables con baja varianza, tanto numéricas como categóricas, ya que aportan escasa información al modelo.
#
# #### 🔹 Selección de características relevantes
# Se emplean técnicas estadísticas como:
# - `SelectKBest` con `f_regression` para las numéricas.
# - `chi2` para las categóricas discretizadas según el precio.
#
# También se analiza la multicolinealidad entre variables numéricas.
#
# #### 🔹 Eliminación de outliers
# Se filtran valores atípicos mediante el rango intercuartílico (IQR) y el modelo `Isolation Forest`, eliminando observaciones con precios o superficies fuera de escala.
#
# #### 🔹 Creación de nuevas variables
# Se generan variables derivadas que capturan relaciones relevantes, como ratios de superficie por dormitorios o baños, edad del inmueble, nivel de lujo y cantidad de servicios cercanos. Estas ayudan al modelo a detectar patrones complejos del mercado inmobiliario.

# %% [markdown]
# Este preprocesamiento permite disponer de un conjunto limpio, reducido y óptimo para entrenar modelos predictivos con mayor precisión y menor riesgo de overfitting.
#
# ---

# %% [markdown]
# ### 🔧 Importación de librerías y carga de datos
# Importamos las principales librerías de análisis, visualización y preprocesamiento. A continuación, cargamos el dataset en formato parquet para su posterior limpieza y análisis.

# %%
# Importaciones y configuración
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, TargetEncoder
from sklearn.compose import ColumnTransformer
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest, f_regression, chi2, VarianceThreshold
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest

# %%
# Dataset
df_final = pd.read_parquet("C:/Users/mario/Downloads/tecnocasa_RentaNetaSeccion.parquet", engine = 'fastparquet')

# %% [markdown]
# ### 📑 Clasificación de variables por tipo
# Identificamos las columnas numéricas, binarias (0/1) y categóricas para poder aplicarles el tratamiento adecuado en etapas posteriores del preprocesamiento.

# %%
# Separar tipos de variables
numericas = [
    'Precio', 'Dormitorios', 'Superficie', 'Num_baños', 'Año_de_construccion', 'Planta_ordinal',
    'Latitud', 'Longitud', 'Precio_m2', 'Longitud_desc', 'Riqueza_desc', 'Polaridad_desc', 
    'Subjetividad_desc', 'Adjetivos_positivos', 'Urgencia_desc', 'announcement_id',
    'ruido_carretera', 'dist_a_carretera', 'ruido_ferrocarril', 'dist_a_ferrocarril', 
    'ruido_urbano', 'dist_a_aglomeracion', 'ruido_aeropuerto', 'dist_a_aeropuerto', 'ruido_promedio', 
    'Renta_Neta_Seccion',  # <--- Sustituye a la antigua Renta_Neta_Media
    'nivel_lujo', 'nivel_modernidad', 'nivel_foto_profesional', 'equilibrio_composicion', 'num_imagenes',
    'color_diversidad', 'color_avg_hue', 'color_avg_saturacion', 'color_avg_valor'
]

binarias = [
    'Metro', 'Renfe', 'Bus', 'Vistas', 'Garaje', 'Trastero', 'Piscina', 'Terraza_balcon', 'Seguridad_portero',
    'Amueblado', 'Calle_tranquila', 'Aire acondicionado', 'Calefaccion', 'Ascensor', 'Jardin', 'Hospital', 
    'Colegio', 'Supermercado', 'Tienda', 'Restaurante', 'Bar', 'Farmacia', 'espacio_abierto'
]

categoricas = [
    'Estado_conservacion', 'Etiqueta', 'Tipo_de_inmueble', 'Tipo_vivienda', 'distrito/ciudad',
    'Localización_normalizada', 'Localizacion_Clave', 'tipo_suelo', 'material_pared', 'tipo_ventana', 
    'altura_techo', 'elementos_estructurales_visibles', 'estilo_principal', 'calidad_iluminacion', 
    'distribucion_espacios', 'espacios_almacenaje', 'zonas_exteriores', 'tecnologia_visible', 'calidad_bano',
    'equipamiento_cocina', 'defectos_visibles', 'distorsion_perspectiva', 'color_principal'
]

# Comprobación de seguridad (opcional, para ver que todo encaja)
vars_totales = numericas + binarias + categoricas
print(f"Total de variables predictoras configuradas: {len(vars_totales)}")
# Out:
# Total de variables predictoras configuradas: 81

# %% [markdown]
# ### 🧹 Limpieza de columnas irrelevantes o redundantes
# Eliminamos variables que no aportan valor predictivo (como enlaces, IDs, columnas derivadas o redundantes con la localización).

# %%
# Limpieza columnas sin valor
columns_to_drop = [
    'Enlace',                   # URL sin valor predictivo
    'announcement_id',          # Identificador único
    'Precio_m2',                # Evita data leakage (derivada de Precio/Superficie)
    'distrito/ciudad',          # Redundante con Localizacion_Clave
    'Localización_normalizada', # Redundante
    'ruido_promedio',           # Resumen de otros ruidos (redundante)
    'Latitud',
    'Longitud',
    'Imagenes_locales', 'Descripción', 'Imagenes', 'geometry',
    'color_main_color'          # Probablemente poco útil, puede codificar muchos valores únicos
]

df_final = df_final.drop(columns=columns_to_drop, errors='ignore')

# %%
# Actualizar variables
numericas = [col for col in numericas if col in df_final.columns]
binarias = [col for col in binarias if col in df_final.columns]
categoricas = [col for col in categoricas if col in df_final.columns]

# %% [markdown]
# ### 🚫 Eliminación de variables con baja varianza
# Descartamos variables numéricas, binarias y categóricas que presentan muy poca variabilidad entre observaciones, ya que probablemente no aporten valor en la predicción.

# %%
vars_validas = [col for col in numericas + binarias if col in df_final.columns]
selector = VarianceThreshold(threshold=0.05)
selector.fit(df_final[vars_validas])

low_variance_num = [col for col in vars_validas
                   if col not in df_final[vars_validas].columns[selector.get_support()]]

print("Numéricas/Binarias con baja varianza:", low_variance_num)
# Out:
# Numéricas/Binarias con baja varianza: ['color_avg_hue', 'color_avg_saturacion', 'color_avg_valor', 'Bus', 'Jardin', 'Colegio']

# %%
low_variance_cat = []
for col in categoricas:
    if col in df_final.columns:
        top_value_ratio = df_final[col].value_counts(normalize=True).iloc[0]
        if top_value_ratio > 0.95:
            low_variance_cat.append(col)
print("Categóricas con baja varianza:", low_variance_cat)
# Out:
# Categóricas con baja varianza: ['altura_techo', 'elementos_estructurales_visibles', 'zonas_exteriores', 'tecnologia_visible', 'defectos_visibles']

# %%
columns_to_drop = list(set(low_variance_num + low_variance_cat))
columns_to_drop = [col for col in columns_to_drop if col in df_final.columns]
df_final = df_final.drop(columns=columns_to_drop)

print(f"Se eliminaron {len(columns_to_drop)} columnas: {columns_to_drop}")
print(f"Nuevo shape: {df_final.shape}")
# Out:
# Se eliminaron 11 columnas: ['altura_techo', 'tecnologia_visible', 'color_avg_valor', 'zonas_exteriores', 'Bus', 'Jardin', 'defectos_visibles', 'Colegio', 'elementos_estructurales_visibles', 'color_avg_saturacion', 'color_avg_hue']
# Nuevo shape: (1015, 63)

# %%
# Actualizar variables
numericas = [col for col in numericas if col in df_final.columns]
binarias = [col for col in binarias if col in df_final.columns]
categoricas = [col for col in categoricas if col in df_final.columns]

# %% [markdown]
# ### 🧮 Feature Selection (variables que más influyen en el Precio)
# Aplicamos SelectKBest con estadística f_regression para identificar las 15 variables numéricas más relevantes en la predicción del precio.

# %%
numerical_features = [col for col in numericas if col != 'Precio']

selector = SelectKBest(score_func=f_regression, k=15)  # Top 15 features
X_selected = selector.fit_transform(df_final[numerical_features], df_final['Precio'])

# Obtener nombres de las features seleccionadas
selected_num_features = df_final[numerical_features].columns[selector.get_support()]
scores = selector.scores_[selector.get_support()]

feature_ranking = pd.DataFrame({
    'Feature': selected_num_features,
    'F_Score': scores
}).sort_values('F_Score', ascending=False)

print("Variables numéricas más informativas:", selected_num_features)
print(feature_ranking)
# Out:
# Variables numéricas más informativas: Index(['Dormitorios', 'Superficie', 'Num_baños', 'Año_de_construccion',
#        'Longitud_desc', 'Riqueza_desc', 'Subjetividad_desc',
#        'Adjetivos_positivos', 'Urgencia_desc', 'ruido_carretera',
#        'Renta_Neta_Seccion', 'nivel_lujo', 'nivel_modernidad',
#        'nivel_foto_profesional', 'equilibrio_composicion'],
#       dtype='object')
#                    Feature     F_Score
# 1               Superficie  850.378172
# 2                Num_baños  740.918136
# 0              Dormitorios  342.711531
# 11              nivel_lujo  216.761541
# 13  nivel_foto_profesional  177.234547
# 14  equilibrio_composicion   84.023924
# 4            Longitud_desc   72.644590
# 5             Riqueza_desc   58.871926
# 10      Renta_Neta_Seccion   37.607294
# 12        nivel_modernidad   35.907949
# 7      Adjetivos_positivos   17.512183
# 8            Urgencia_desc   15.242744
# 3      Año_de_construccion   11.564585
# 9          ruido_carretera    7.675591
# 6        Subjetividad_desc    5.935182

# %% [markdown]
# Convertimos el precio a una variable discreta (Precio_bin) para poder aplicar la prueba de independencia chi2, seleccionando las 10 variables categóricas con mayor poder explicativo.

# %%
# Paso 1: Discretizar el precio
df_final['Precio_bin'] = pd.qcut(df_final['Precio'], q=4, labels=False)

# Paso 2: Codificar las categóricas
X_cat = df_final[categoricas].copy()
for col in X_cat.columns:
    X_cat[col] = X_cat[col].astype(str)
    X_cat[col] = LabelEncoder().fit_transform(X_cat[col])

# Paso 3: Chi2
selector = SelectKBest(score_func=chi2, k=10)
selector.fit(X_cat, df_final['Precio_bin'])

selected_cat_features = list(X_cat.columns[selector.get_support()])
df_final = df_final.drop(columns = "Precio_bin")
print("Variables categóricas más informativas:", selected_cat_features)
# Out:
# Variables categóricas más informativas: ['Etiqueta', 'Tipo_de_inmueble', 'Tipo_vivienda', 'Localizacion_Clave', 'tipo_suelo', 'tipo_ventana', 'estilo_principal', 'calidad_iluminacion', 'equipamiento_cocina', 'color_principal']

# %% [markdown]
# ### 🧩 Detección de multicolinealidad entre variables numéricas
# Calculamos la matriz de correlaciones para eliminar variables altamente correlacionadas entre sí (r > 0.9), lo cual puede afectar negativamente al rendimiento y la interpretabilidad del modelo.

# %%
corr_matrix = df_final[numericas].corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
high_corr = [column for column in upper.columns if any(upper[column] > 0.9)]

print("Variables numéricas muy correlacionadas:", high_corr)
# Out:
# Variables numéricas muy correlacionadas: ['Riqueza_desc', 'Subjetividad_desc', 'dist_a_ferrocarril', 'dist_a_aeropuerto']

# %%
to_drop = set()

for col in high_corr:
    corr_targets = upper[col][upper[col] > 0.9].index.tolist()
    
    # Conservar la variable con mayor correlación con el precio
    if col in df_final.columns:
        best_feature = max([col] + corr_targets, 
                          key=lambda x: abs(df_final[x].corr(df_final['Precio'])))
        
        to_drop.update([f for f in corr_targets + [col] if f != best_feature])

print("\nVariables a eliminar (redundantes):", to_drop)
# Out:
# Variables a eliminar (redundantes): {'dist_a_ferrocarril', 'Polaridad_desc', 'dist_a_aeropuerto', 'Riqueza_desc'}

# %%
df_final = df_final.drop(columns=[col for col in to_drop if col in df_final.columns])
numericas = [col for col in numericas if col in df_final.columns]
remaining_corr = df_final[numericas].corr().abs()

# %%
df_final.columns
# Out:
# Index(['Precio', 'Dormitorios', 'Superficie', 'Num_baños', 'Metro', 'Renfe',
#        'Farmacia', 'Bar', 'Restaurante', 'Hospital', 'Supermercado', 'Tienda',
#        'Vistas', 'Estado_conservacion', 'Garaje', 'Trastero', 'Piscina',
#        'Terraza_balcon', 'Seguridad_portero', 'Etiqueta', 'Amueblado',
#        'Calle_tranquila', 'Aire acondicionado', 'Tipo_de_inmueble',
#        'Año_de_construccion', 'Calefaccion', 'Ascensor', 'Tipo_vivienda',
#        'Planta_ordinal', 'Longitud_desc', 'Subjetividad_desc',
#        'Adjetivos_positivos', 'Urgencia_desc', 'tipo_suelo', 'material_pared',
#        'tipo_ventana', 'nivel_lujo', 'nivel_modernidad', 'estilo_principal',
#        'calidad_iluminacion', 'espacio_abierto', 'distribucion_espacios',
#        'espacios_almacenaje', 'calidad_bano', 'equipamiento_cocina',
#        'nivel_foto_profesional', 'equilibrio_composicion',
#        'distorsion_perspectiva', 'num_imagenes', 'color_diversidad',
#        'color_principal', 'ruido_carretera', 'dist_a_carretera',
#        'ruido_ferrocarril', 'ruido_urbano', 'dist_a_aglomeracion',
#        'ruido_aeropuerto', 'Renta_Neta_Seccion', 'Localizacion_Clave'],
#       dtype='object')

# %%
print(f"Shape: {df_final.shape}")
# Out:
# Shape: (1015, 59)

# %% [markdown]
# ### 🏙️ Filtrado de barrios con pocos inmuebles
# Se eliminan los barrios con menos de 4 viviendas registradas para garantizar que cada zona tenga suficiente representatividad estadística en el modelo.

# %%
min_inmuebles = 4

# Contar cuántos inmuebles hay por barrio
conteo_barrios = df_final['Localizacion_Clave'].value_counts()

# Barrios que se mantienen
barrios_validos = conteo_barrios[conteo_barrios >= min_inmuebles].index

# Barrios que se eliminan
barrios_eliminados = conteo_barrios[conteo_barrios < min_inmuebles].index

print("Barrios que se eliminarán (menos de", min_inmuebles, "inmuebles):")
for b in barrios_eliminados:
    print(f"- {b} ({conteo_barrios[b]} inmuebles)")

# Filtrar dataframe
df_final = df_final[df_final['Localizacion_Clave'].isin(barrios_validos)]

print(f"Nuevo shape: {df_final.shape}")
# Out:
# Barrios que se eliminarán (menos de 4 inmuebles):
# - ALGETE (3 inmuebles)
# - TRES CANTOS (3 inmuebles)
# - BOADILLA DEL MONTE (2 inmuebles)
# - SANTOS DE LA HUMOSA, LOS (2 inmuebles)
# - SAN FERNANDO DE HENARES (2 inmuebles)
# - ÁLAMO, EL (2 inmuebles)
# - ALCOBENDAS (2 inmuebles)
# - SAN AGUSTÍN DEL GUADALIX (2 inmuebles)
# - COLLADO MEDIANO (1 inmuebles)
# - MOLAR, EL (1 inmuebles)
# - VILLANUEVA DEL PARDILLO (1 inmuebles)
# - BECERRIL DE LA SIERRA (1 inmuebles)
# - VILLANUEVA DE LA CAÑADA (1 inmuebles)
# - COBEÑA (1 inmuebles)
# - GUADARRAMA (1 inmuebles)
# - PEDREZUELA (1 inmuebles)
# - SERRANILLOS DEL VALLE (1 inmuebles)
# - VALDEOLMOS-ALALPARDO (1 inmuebles)
# Nuevo shape: (987, 59)

# %% [markdown]
# ### 🧹 Eliminación de outliers mediante IQR e Isolation Forest
# Se aplican dos métodos complementarios para detectar y eliminar valores atípicos en variables clave como precio, superficie, dormitorios y baños.
# El enfoque combina el rango intercuartílico (IQR) con el algoritmo *Isolation Forest* para identificar propiedades con valores anómalos.

# %%
# Outliers
num_cols_outliers = ['Precio', 'Superficie', 'Dormitorios', 'Num_baños']
def remove_outliers_iqr(df, cols, factor=2.0):
    for col in cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        mask = (df[col] >= Q1 - factor * IQR) & (df[col] <= Q3 + factor * IQR)
        df = df[mask]
    return df

df_final = remove_outliers_iqr(df_final, num_cols_outliers, factor=2.0)

iso = IsolationForest(contamination=0.02, random_state=42)
mask_iso = iso.fit_predict(df_final[num_cols_outliers]) == 1
df_final = df_final[mask_iso]
print(f"Nuevo shape: {df_final.shape}")
# Out:
# Nuevo shape: (855, 59)

# %% [markdown]
# ### 🧮 Feature Engineering: creación de variables derivadas
# Se generan nuevas características que ayudan al modelo a capturar relaciones no lineales entre variables.
# Estas incluyen ratios de espacio por habitación, edad del inmueble, nivel de lujo ponderado y cantidad de servicios cercanos.

# %%
# Feature engineering
df_final['Dormitorios_por_m2'] = df_final['Dormitorios'] / df_final['Superficie']
df_final['Banos_por_m2'] = df_final['Num_baños'] / df_final['Superficie']
df_final['Servicios_cercanos'] = df_final[['Metro','Renfe','Farmacia','Bar','Restaurante','Hospital','Supermercado','Tienda']].sum(axis=1)
df_final['Edad_inmueble'] = 2025 - df_final['Año_de_construccion']
df_final['Recien_reformado'] = (df_final['Estado_conservacion'] == 'Bueno').astype(int)
df_final['Superficie_x_Lujo'] = df_final['Superficie'] * df_final['nivel_lujo']

# %%
#df_final.to_parquet("C:/Users/mario/Downloads/tecnocasa_modeloRentaSeccion.parquet", index = False)

# %%
df_final.iloc[:5,:15]
# Out:
#      Precio  Dormitorios  Superficie  Num_baños  Metro  Renfe  Farmacia  Bar  \
# 0  368000.0            4       131.0          2      0      1         1    1
# 1  331000.0            3       139.0          2      0      0         1    0
# 2  304000.0            3       126.0          2      1      0         1    1
# 4  175000.0            2        46.0          1      1      1         1    1
# 5  255000.0            3        81.0          1      1      1         1    1
#
#    Restaurante  Hospital  Supermercado  Tienda  Vistas Estado_conservacion  \
# 0            1         1             1       1       0         Desconocido
# 1            0         0             0       0       0         Desconocido
# 2            1         0             1       1       1         Desconocido
# 4            1         0             1       1       0         Desconocido
# 5            1         1             1       1       0         Desconocido
#
#    Garaje
# 0       0
# 1       1
# 2       1
# 4       0
# 5       0

# %%
df_final.iloc[:5,15:30]
# Out:
#    Trastero  Piscina  Terraza_balcon  Seguridad_portero     Etiqueta  \
# 0         0        1               0                  0  Desconocida
# 1         0        1               0                  0            F
# 2         1        0               1                  0  Desconocida
# 4         0        0               1                  0            B
# 5         0        1               1                  0            D
#
#    Amueblado  Calle_tranquila  Aire acondicionado Tipo_de_inmueble  \
# 0          0                1                   1          Popular
# 1          0                0                   0            Media
# 2          0                0                   1          Popular
# 4          0                0                   0            Media
# 5          0                0                   0          Popular
#
#    Año_de_construccion  Calefaccion  Ascensor Tipo_vivienda  Planta_ordinal  \
# 0                 1991            0         0          piso               3
# 1                 1977            1         0          casa               2
# 2                 1991            1         1          piso               4
# 4                 1967            1         0          piso               1
# 5                 1976            1         1          piso               3
#
#    Longitud_desc
# 0          251.0
# 1          159.0
# 2          249.0
# 4           94.0
# 5          155.0

# %%
df_final.iloc[:5,30:45]
# Out:
#    Subjetividad_desc  Adjetivos_positivos  Urgencia_desc tipo_suelo  \
# 0           0.400000                  1.0            0.0    parquet
# 1           0.000000                  1.0            0.0   cerámica
# 2           0.600000                  2.0            1.0   cerámica
# 4           0.250000                  0.0            0.0   cerámica
# 5           0.916667                  2.0            1.0   cerámica
#
#   material_pared tipo_ventana  nivel_lujo  nivel_modernidad estilo_principal  \
# 0        pintura    corredera         3.6               3.8     convencional
# 1        pintura    corredera         3.8               2.8          clásico
# 2        pintura    corredera         3.2               4.0     convencional
# 4        pintura    corredera         3.2               3.8     convencional
# 5        pintura    corredera         3.2               3.4     convencional
#
#   calidad_iluminacion  espacio_abierto distribucion_espacios  \
# 0               buena            False          convencional
# 1             regular            False          convencional
# 2             regular            False          convencional
# 4               buena            False          convencional
# 5             regular            False          convencional
#
#   espacios_almacenaje calidad_bano    equipamiento_cocina
# 0              normal     estándar                 básica
# 1            limitado     estándar                 básica
# 2              normal     estándar                 básica
# 4            limitado     estándar  parcialmente equipada
# 5            limitado     estándar                 básica

# %%
df_final.iloc[:5,45:60]
# Out:
#    nivel_foto_profesional  equilibrio_composicion distorsion_perspectiva  \
# 0                     7.6                     6.6                ninguna
# 1                     6.4                     5.6                ninguna
# 2                     6.4                     6.0                ninguna
# 4                     7.4                     6.4                ninguna
# 5                     6.2                     6.4                ninguna
#
#    num_imagenes  color_diversidad color_principal  ruido_carretera  \
# 0             5                 3         #FFFFFF             30.0
# 1             5                 3         #228B22             30.0
# 2             5                 3         #A77A54             30.0
# 4             5                 3         #F5F5DC             50.0
# 5             5                 3         #D2B48C             30.0
#
#    dist_a_carretera  ruido_ferrocarril  ruido_urbano  dist_a_aglomeracion  \
# 0       1100.000000               30.0          65.0             0.118166
# 1       1100.000000               30.0          30.0          1600.000000
# 2       1100.000000               55.0          30.0          1600.000000
# 4        764.722856               30.0          30.0          1600.000000
# 5       1100.000000               30.0          30.0          1600.000000
#
#    ruido_aeropuerto  Renta_Neta_Seccion     Localizacion_Clave  \
# 0              30.0             39778.0      ALCALÁ DE HENARES
# 1              30.0             38236.0  SAN MARTÍN DE LA VEGA
# 2              30.0             33418.0        ARGANDA DEL REY
# 4              30.0             32139.0               MÓSTOLES
# 5              30.0             42154.0               ALCORCÓN
#
#    Dormitorios_por_m2
# 0            0.030534
# 1            0.021583
# 2            0.023810
# 4            0.043478
# 5            0.037037

# %%
df_final.iloc[:5,60:]
# Out:
#    Banos_por_m2  Servicios_cercanos  Edad_inmueble  Recien_reformado  \
# 0      0.015267                   7             34                 0
# 1      0.014388                   1             48                 0
# 2      0.015873                   6             34                 0
# 4      0.021739                   7             58                 0
# 5      0.012346                   8             49                 0
#
#    Superficie_x_Lujo
# 0              471.6
# 1              528.2
# 2              403.2
# 4              147.2
# 5              259.2
